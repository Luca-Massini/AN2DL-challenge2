# %% [markdown]
# <a href="https://colab.research.google.com/github/Luca-Massini/AN2DL-challenge/blob/master/Single_networks/Weedelec_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
import os

import tensorflow as tf
import numpy as np

# Set the seed for random operations. 
# This let our experiments to be reproducible. 
SEED = 1234
tf.random.set_seed(SEED)

# %%
cwd = os.getcwd()
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ImageDataGenerator
# ------------------

from tensorflow.keras.preprocessing.image import ImageDataGenerator

apply_data_augmentation = True

# Create training ImageDataGenerator object
# We need two different generators for images and corresponding masks
if apply_data_augmentation:
    img_data_gen = ImageDataGenerator(rotation_range=90,
                                      width_shift_range=0.4,
                                      height_shift_range=0.4,
                                      zoom_range=0.6,
                                      horizontal_flip=True,
                                      vertical_flip=True,
                                      fill_mode='reflect',
                                      brightness_range =[0.8,1.2])
    mask_data_gen = ImageDataGenerator(rotation_range=90,
                                       width_shift_range=0.4,
                                       height_shift_range=0.4,
                                       zoom_range=0.6,
                                       horizontal_flip=True,
                                       vertical_flip=True,
                                       fill_mode='reflect')

# %%
from PIL import Image

class CustomDataset(tf.keras.utils.Sequence):

  """
    CustomDataset inheriting from tf.keras.utils.Sequence.

    3 main methods:
      - __init__: save dataset params like directory, filenames..
      - __len__: return the total number of samples in the dataset
      - __getitem__: return a sample from the dataset

    Note: 
      - the custom dataset return a single sample from the dataset. Then, we use 
        a tf.data.Dataset object to group samples into batches.
      - in this case we have a different structure of the dataset in memory. 
        We have all the images in the same folder and the training and validation splits
        are defined in text files.

  """

  def __init__(self, dataset_dir, which_subset, img_generator=None, mask_generator=None, 
               preprocessing_function=None, out_shape=[512, 384],validation_part=0.2,projects=['Weedelec','Pead','Roseau','Bipbip'],plants=['Haricot','Mais']):
    self.png_or_jpg = []
    subset_filenames = []
    subset_direc = []
    for project in projects :
      for plant in plants :
        path=os.path.join(dataset_dir,project,plant)
        list_ = os.listdir(os.path.join(path,'Images')) # dir is your directory path
        number_files = len(list_)

        training_num_max = int(number_files - int(number_files *  validation_part))
        print("training files: ", training_num_max, "validation_part: ", number_files - training_num_max)
        if which_subset == 'training':
          number_max = training_num_max
          for ii in range(0,number_max):
            subset_filenames.append(os.path.splitext(list_[ii])[0])
            subset_direc.append(path)
            if project!='Roseau':
              self.png_or_jpg.append(1)
            else:
              self.png_or_jpg.append(0)
        elif which_subset == 'validation':
          number_max = number_files - training_num_max
          for ii in range(number_files - 1, number_files - number_max, -1):
            subset_filenames.append(os.path.splitext(list_[ii])[0])
            subset_direc.append(path)
            if project!='Roseau':
              self.png_or_jpg.append(1)
            else:
              self.png_or_jpg.append(0)


    self.which_subset = which_subset
    self.dataset_dir = dataset_dir
    self.subset_direc = subset_direc
    self.subset_filenames = subset_filenames
    self.img_generator = img_generator
    self.mask_generator = mask_generator
    self.preprocessing_function = preprocessing_function
    self.out_shape = out_shape

  def __len__(self):
    return len(self.subset_filenames)

  def read_rgb_mask(img_path):
    '''
    img_path: path to the mask file
    Returns the numpy array containing target values
    '''

    mask_img = Image.open(img_path)
    mask_arr = np.array(mask_img)

    new_mask_arr = np.zeros(mask_arr.shape[:2], dtype=mask_arr.dtype)

    # Use RGB dictionary in 'RGBtoTarget.txt' to convert RGB to target
    new_mask_arr[np.where(np.all(mask_arr == [216, 124, 18], axis=-1))] = 0
    new_mask_arr[np.where(np.all(mask_arr == [255, 255, 255], axis=-1))] = 1
    new_mask_arr[np.where(np.all(mask_arr == [216, 67, 82], axis=-1))] = 2

    return new_mask_arr
  
  def __getitem__(self, index):
    # Read Image
    curr_filename = self.subset_filenames[index]
    curr_dir = self.subset_direc[index]
    if self.png_or_jpg[index] != 0:
      img = Image.open(os.path.join(curr_dir, 'Images', curr_filename + '.jpg'))
    else:
      img = Image.open(os.path.join(curr_dir, 'Images', curr_filename + '.png'))
    mask = Image.open(os.path.join(curr_dir, 'Masks', curr_filename + '.png'))

    # Resize image 
    img = img.resize(self.out_shape)
    mask = mask.resize(self.out_shape, resample=Image.NEAREST)

    mask_arr = np.array(mask)
    new_mask_arr = np.zeros(mask_arr.shape[:2], dtype=mask_arr.dtype)

    # Use RGB dictionary in 'RGBtoTarget.txt' to convert RGB to target
    new_mask_arr[np.where(np.all(mask_arr == [216, 124, 18], axis=-1))] = 0
    new_mask_arr[np.where(np.all(mask_arr == [255, 255, 255], axis=-1))] = 1
    new_mask_arr[np.where(np.all(mask_arr == [216, 67, 82], axis=-1))] = 2
    
    img_arr = np.array(img)
    mask_arr = new_mask_arr

    # in this dataset 255 mask label is assigned to an additional class, which corresponds 
    # to the contours of the objects. We remove it for simplicity.
    #mask_arr[mask_arr == 255] = 0  

    mask_arr = np.expand_dims(mask_arr, -1)

    if self.which_subset == 'training':
      if self.img_generator is not None and self.mask_generator is not None:
        # Perform data augmentation
        # We can get a random transformation from the ImageDataGenerator using get_random_transform
        # and we can apply it to the image using apply_transform
        img_t = self.img_generator.get_random_transform(img_arr.shape, seed=SEED)
        mask_t = self.mask_generator.get_random_transform(mask_arr.shape, seed=SEED)
        img_arr = self.img_generator.apply_transform(img_arr, img_t)
        # ImageDataGenerator use bilinear interpolation for augmenting the images.
        # Thus, when applied to the masks it will output 'interpolated classes', which
        # is an unwanted behaviour. As a trick, we can transform each class mask 
        # separately and then we can cast to integer values (as in the binary segmentation notebook).
        # Finally, we merge the augmented binary masks to obtain the final segmentation mask.
        out_mask = np.zeros_like(mask_arr)
        for c in np.unique(mask_arr):
          if c > 0:
            curr_class_arr = np.float32(mask_arr == c)
            curr_class_arr = self.mask_generator.apply_transform(curr_class_arr, mask_t)
            # from [0, 1] to {0, 1}
            curr_class_arr = np.uint8(curr_class_arr)
            # recover original class
            curr_class_arr = curr_class_arr * c 
            out_mask += curr_class_arr
    else:
      out_mask = mask_arr
    
    if self.preprocessing_function is not None:
        img_arr = self.preprocessing_function(img_arr)

    return img_arr, np.float32(out_mask)

# %%
img_h = 384
img_w = 512
dataset = CustomDataset('/content/drive/MyDrive/Development_Dataset/Training/', 'training', 
                        img_generator=img_data_gen, mask_generator=mask_data_gen,
                        preprocessing_function=None,validation_part=0.2,projects=['Weedelec'],plants=['Haricot', 'Mais'])
dataset_valid = CustomDataset('/content/drive/MyDrive/Development_Dataset/Training/', 'validation', 
                              preprocessing_function=None,validation_part=0.2,projects=['Weedelec'],plants=['Haricot', 'Mais'])
# Out:
# training files:  72 validation_part:  18
# training files:  72 validation_part:  18
# training files:  72 validation_part:  18
# training files:  72 validation_part:  18

# %%
img_h = 384
img_w = 512

train_dataset = tf.data.Dataset.from_generator(lambda: dataset,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))
train_dataset = train_dataset.shuffle(8, reshuffle_each_iteration=True)

bs = 10
train_dataset = train_dataset.batch(bs)

train_dataset = train_dataset.repeat()

valid_dataset = tf.data.Dataset.from_generator(lambda: dataset_valid,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([img_h, img_w, 3], [img_h, img_w,1]))
valid_dataset = valid_dataset.batch(bs)

valid_dataset = valid_dataset.repeat()

# %%
# -------------------------
import time
from matplotlib import cm
import matplotlib.pyplot as plt

# %matplotlib inline

# Assign a color to each class
evenly_spaced_interval = np.linspace(0, 1, 3)
colors = [cm.rainbow(x) for x in evenly_spaced_interval]

iterator = iter(valid_dataset)

# %%
#-------------
#Visualize the images and the masks
#--------------
fig, ax = plt.subplots(1, 2)

augmented_img, target = next(iterator)
augmented_img = augmented_img[0]   # First element

target = np.array(target[0, ..., 0])   # First element (squeezing channel dimension)

print(np.unique(target))

target_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, 3):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(augmented_img))
ax[1].imshow(np.uint8(target_img))

plt.show()
# Out:
# [0. 1. 2.]

# %%
def create_model(start_f):
  input_shape = [img_h, img_w, 3]
  inputs = tf.keras.Input(shape=(img_h, img_w, 3))
  i_1 = tf.keras.layers.Conv2D(filters = start_f, 
                                kernel_size = (2,2),
                                strides=(1, 1),
                                padding='same')(inputs)
  i_2 = tf.keras.layers.Conv2D(filters = start_f, 
                                kernel_size = (2,2),
                                strides=(1, 1),
                                padding='same')(i_1)
  x_0 = tf.keras.layers.Conv2D(filters = start_f, 
                                kernel_size = (3,3),
                                strides=(1, 1),
                                padding='same')(inputs)
  x_1 = tf.keras.layers.Conv2D(filters = start_f, 
                                kernel_size = (3,3),
                                strides=(1, 1),
                                padding='same')(x_0)
  i_3 = tf.keras.layers.Average()([i_2, x_1])
  input_shape = None


  start_f *= 2
  x_2 = tf.keras.layers.BatchNormalization(axis=-1)(i_3)
  x_3  = tf.keras.layers.Activation('relu')(x_2)
  x_4 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(x_3)
  p_1 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(x_4)
  p_2 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(p_1)
  c_1 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(x_4)
  x_5 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(c_1)
  u_1 = tf.keras.layers.Average()([p_2, x_5])
  x_6 = tf.keras.layers.BatchNormalization(axis=-1)(u_1)
  x_7 = tf.keras.layers.Activation('relu')(x_6)
  x_8 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(x_7)



  start_f *= 2
  p_3 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(x_8)
  p_4 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(p_3)
  c_2 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(x_8)
  x_9 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(c_2)
  u_2 = tf.keras.layers.Average()([p_4, x_9])
  y_1 = tf.keras.layers.BatchNormalization(axis=-1)(u_2)
  y_2 = tf.keras.layers.Activation('relu')(y_1)
  y_3 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(y_2)




  start_f *= 2
  p_5 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(y_3)
  p_6 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(p_5)
  c_3 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(y_3)
  y_4 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(c_3)
  u_3 = tf.keras.layers.Average()([p_6, y_4])
  y_5 = tf.keras.layers.BatchNormalization(axis=-1)(u_3)
  y_6 = tf.keras.layers.Activation('relu')(y_5)
  y_7 = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(y_6)





  start_f *= 2
  p_7 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(y_7)
  p_8 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same')(p_7)
  c_4 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(y_7)
  y_8 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(c_4)
  u_4 = tf.keras.layers.Average()([y_8, p_8])
  y_9 = tf.keras.layers.BatchNormalization(axis=-1)(u_4)
  z_1 = tf.keras.layers.Activation('relu')(y_9)



  #MIDDLE BLOCK
  m_1 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(z_1)
  m_2 = tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same')(m_1)
  m_3 = tf.keras.layers.BatchNormalization(axis=-1)(m_2)
  m_4 = tf.keras.layers.Activation('relu')(m_3)





  #DECODER
  start_f = start_f // 2
  g_1 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(2, 2), padding='same')(m_4)
  g_2 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(1, 1), padding='same')(g_1)
  d_2 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(2, 2), padding='same')(m_4)
  d_3 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(1,1), padding='same')(d_2)
  u_5 = tf.keras.layers.Average()([g_2, d_3])
  d_4 = tf.keras.layers.ReLU()(u_5)
  d_6 = tf.keras.layers.Add()([d_4,y_6])

  start_f = start_f // 2
  g_3 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(2, 2), padding='same')(d_6)
  g_4 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(1, 1), padding='same')(g_3)
  d_7 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(2, 2), padding='same')(d_6)
  d_8 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(1, 1), padding='same')(d_7)
  u_6 = tf.keras.layers.Average()([d_8, g_4])
  d_9 = tf.keras.layers.ReLU()(u_6)
  e_1 = tf.keras.layers.Add()([d_9,y_2])


  start_f = start_f // 2
  g_5 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(2, 2), padding='same')(e_1)
  g_6 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(1, 1), padding='same')(g_5)
  e_2 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(2, 2), padding='same')(e_1)
  e_3 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(1, 1), padding='same')(e_2)
  u_7 = tf.keras.layers.Average()([e_3, g_6])
  e_4 = tf.keras.layers.ReLU()(u_7)
  e_6 = tf.keras.layers.Add()([e_4,x_7])

  start_f = start_f // 2
  g_7 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(2, 2), padding='same')(e_6)
  g_8 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(2,2), strides=(1, 1), padding='same')(g_7)
  e_8 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(2, 2), padding='same')(e_6)
  e_9 = tf.keras.layers.Conv2DTranspose(filters=start_f, kernel_size=(3,3), strides=(1,1), padding='same')(e_8)
  u_8 = tf.keras.layers.Average()([g_8, e_9])
  f_1 = tf.keras.layers.ReLU()(u_8)
  f_2 = tf.keras.layers.Add()([f_1,x_3])
  h = tf.keras.layers.Dropout(0.4, seed=SEED)(f_2)


  
  last = tf.keras.layers.Conv2D(filters=3,
                                kernel_size=(1, 1),
                                strides=(1, 1),
                                padding='same',
                                activation='softmax')(h)
  model_1 = tf.keras.Model(inputs=inputs, outputs=last)
  print("first model summary")
  model_1.summary()

  return model_1

# %%
model=create_model(start_f=20)
# Out:
# first model summary
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 384, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 384, 512, 20) 260         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 384, 512, 20) 560         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 384, 512, 20) 1620        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 384, 512, 20) 3620        conv2d_2[0][0]
# __________________________________________________________________________________________________
# average (Average)               (None, 384, 512, 20) 0           conv2d_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 384, 512, 20) 80          average[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 384, 512, 20) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 192, 256, 20) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 192, 256, 40) 3240        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 192, 256, 40) 7240        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 192, 256, 40) 6440        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 192, 256, 40) 14440       conv2d_6[0][0]
# __________________________________________________________________________________________________
# average_1 (Average)             (None, 192, 256, 40) 0           conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 192, 256, 40) 160         average_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 192, 256, 40) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 96, 128, 40)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 96, 128, 80)  12880       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 96, 128, 80)  28880       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 96, 128, 80)  25680       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 96, 128, 80)  57680       conv2d_10[0][0]
# __________________________________________________________________________________________________
# average_2 (Average)             (None, 96, 128, 80)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 96, 128, 80)  320         average_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 96, 128, 80)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 64, 80)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 48, 64, 160)  51360       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 64, 160)  115360      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 64, 160)  102560      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 48, 64, 160)  230560      conv2d_14[0][0]
# __________________________________________________________________________________________________
# average_3 (Average)             (None, 48, 64, 160)  0           conv2d_13[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 48, 64, 160)  640         average_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 48, 64, 160)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 32, 160)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 24, 32, 320)  461120      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 24, 32, 320)  205120      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 24, 32, 320)  921920      conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 24, 32, 320)  409920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# average_4 (Average)             (None, 24, 32, 320)  0           conv2d_19[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 24, 32, 320)  1280        average_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 24, 32, 320)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 24, 32, 320)  921920      activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 24, 32, 320)  921920      conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 24, 32, 320)  1280        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 24, 32, 320)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 48, 64, 160)  204960      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 48, 64, 160)  460960      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 48, 64, 160)  230560      conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 48, 64, 160)  230560      conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# average_5 (Average)             (None, 48, 64, 160)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 48, 64, 160)  0           average_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 48, 64, 160)  0           re_lu[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 96, 128, 80)  115280      add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 96, 128, 80)  51280       add[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 96, 128, 80)  57680       conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 96, 128, 80)  25680       conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# average_6 (Average)             (None, 96, 128, 80)  0           conv2d_transpose_7[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 96, 128, 80)  0           average_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 128, 80)  0           re_lu_1[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 192, 256, 40) 28840       add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 192, 256, 40) 12840       add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 192, 256, 40) 14440       conv2d_transpose_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 192, 256, 40) 6440        conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# average_7 (Average)             (None, 192, 256, 40) 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 192, 256, 40) 0           average_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 256, 40) 0           re_lu_2[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 384, 512, 20) 3220        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_14 (Conv2DTran (None, 384, 512, 20) 7220        add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_13 (Conv2DTran (None, 384, 512, 20) 1620        conv2d_transpose_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_15 (Conv2DTran (None, 384, 512, 20) 3620        conv2d_transpose_14[0][0]
# __________________________________________________________________________________________________
# average_8 (Average)             (None, 384, 512, 20) 0           conv2d_transpose_13[0][0]
#                                                                  conv2d_transpose_15[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 384, 512, 20) 0           average_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 384, 512, 20) 0           re_lu_3[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 384, 512, 20) 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 384, 512, 3)  63          dropout[0][0]
# ==================================================================================================
# Total params: 5,963,323
# Trainable params: 5,961,443
# Non-trainable params: 1,880
# __________________________________________________________________________________________________

# %%
# Optimization params
# -------------------

# Loss
# Sparse Categorical Crossentropy to use integers (mask) instead of one-hot encoded labels
loss = tf.keras.losses.SparseCategoricalCrossentropy() 
# learning rate
lr = 1e-4
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
# -------------------

# Here we define the intersection over union for each class in the batch.
# Then we compute the final iou as the mean over classes
def meanIoU(y_true, y_pred):
    # get predicted class from softmax
    y_pred = tf.expand_dims(tf.argmax(y_pred, -1), -1)

    per_class_iou = []

    for i in range(1,3): # exclude the background class 0
      # Get prediction and target related to only a single class (i)
      class_pred = tf.cast(tf.where(y_pred == i, 1, 0), tf.float32)
      class_true = tf.cast(tf.where(y_true == i, 1, 0), tf.float32)
      intersection = tf.reduce_sum(class_true * class_pred)
      union = tf.reduce_sum(class_true) + tf.reduce_sum(class_pred) - intersection
    
      iou = (intersection + 1e-7) / (union + 1e-7)
      per_class_iou.append(iou)

    return tf.reduce_mean(per_class_iou)

# Validation metrics
# ------------------
metrics = ['accuracy', meanIoU]
# ------------------

# Compile Model
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
import os
from datetime import datetime

cwd = os.getcwd()

exps_dir = os.path.join(cwd, 'drive/My Drive/Keras4/', 'multiclass_segmentation_experiments')
if not os.path.exists(exps_dir):
    os.makedirs(exps_dir)

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'CNN'

exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
if not os.path.exists(exp_dir):
    os.makedirs(exp_dir)
    
callbacks = []

# Model checkpoint
# ----------------
ckpt_dir = os.path.join(exp_dir, 'ckpts')
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)

ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp_{epoch:02d}.ckpt'), 
                                                   save_weights_only=True) 
callbacks.append(ckpt_callback)

# Visualize Learning on Tensorboard
# ---------------------------------
tb_dir = os.path.join(exp_dir, 'tb_logs')
if not os.path.exists(tb_dir):
    os.makedirs(tb_dir)
    
# By default shows losses and metrics for both training and validation
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir,
                                             profile_batch=0,
                                             histogram_freq=0)  
callbacks.append(tb_callback)

# Early Stopping
# --------------
early_stop = True
if early_stop:
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
    callbacks.append(es_callback)


history = model.fit(x=train_dataset,
          epochs=20,  #### set repeat in training dataset
          steps_per_epoch=len(dataset),
          validation_data=valid_dataset,
          validation_steps=len(dataset_valid), 
          callbacks=callbacks)
# Out:
# Epoch 1/20
# 144/144 [==============================] - 1411s 10s/step - loss: 0.8482 - accuracy: 0.6396 - meanIoU: 0.0674 - val_loss: 0.5492 - val_accuracy: 0.7422 - val_meanIoU: 0.0293
# Epoch 2/20
# 144/144 [==============================] - 1230s 9s/step - loss: 0.1638 - accuracy: 0.9346 - meanIoU: 0.2123 - val_loss: 0.0962 - val_accuracy: 0.9601 - val_meanIoU: 0.2939
# Epoch 3/20
# 144/144 [==============================] - 1233s 9s/step - loss: 0.1389 - accuracy: 0.9427 - meanIoU: 0.2630 - val_loss: 0.0898 - val_accuracy: 0.9737 - val_meanIoU: 0.3559
# Epoch 4/20
# 144/144 [==============================] - 1282s 9s/step - loss: 0.1215 - accuracy: 0.9494 - meanIoU: 0.2826 - val_loss: 0.0824 - val_accuracy: 0.9764 - val_meanIoU: 0.3499
# Epoch 5/20
# 144/144 [==============================] - 1347s 9s/step - loss: 0.1056 - accuracy: 0.9563 - meanIoU: 0.3028 - val_loss: 0.1032 - val_accuracy: 0.9753 - val_meanIoU: 0.3421
# Epoch 6/20
# 144/144 [==============================] - 1358s 9s/step - loss: 0.1055 - accuracy: 0.9570 - meanIoU: 0.3451 - val_loss: 0.1008 - val_accuracy: 0.9654 - val_meanIoU: 0.3126

# %%
for layer in model.layers:
  layer.trainable = False

# %%
def create_second_model(depth, start_f):

    model_1 = tf.keras.Sequential()
    
    # Encoder
    # -------
    model_1.add(model)
    
    for i in range(depth):
      model_1.add(tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(2, 2),
                      strides = (1,1),
                      padding = 'same'))
      model_1.add(tf.keras.layers.Conv2D(filters=start_f, 
                      kernel_size=(3, 3),
                      strides = (1,1),
                      padding = 'same'))
      model_1.add(tf.keras.layers.BatchNormalization(axis=-1))
      model_1.add(tf.keras.layers.Activation('relu'))
      model_1.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2)))
      start_f *= 2
        
    # Decoder
    # -------
    for i in range(depth):
        model_1.add(tf.keras.layers.Conv2DTranspose(filters=start_f,
                                                    kernel_size=(2, 2),
                                                    strides=(2, 2),
                                                    padding='same'))
        model_1.add(tf.keras.layers.Conv2D(filters=start_f,
                                         kernel_size=(3, 3),
                                         strides=(1, 1),
                                         padding='same'))
        model_1.add(tf.keras.layers.ReLU())

        start_f = start_f // 2
    model_1.add(tf.keras.layers.Dropout(0.4, seed=SEED))
    # Prediction Layer
    # ----------------
    model_1.add(tf.keras.layers.Conv2D(filters=3,
                                     kernel_size=(1, 1),
                                     strides=(1, 1),
                                     padding='same',
                                     activation='softmax'))
    
    print("Whole network structure summary")
    model_1.summary()
    
    return model_1

# %%
model_2 = create_second_model(depth=4, start_f=20)
# Out:
# Whole network structure summary
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 384, 512, 3)       5963323
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 384, 512, 20)      260
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 384, 512, 20)      3620
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 384, 512, 20)      80
# _________________________________________________________________
# activation_12 (Activation)   (None, 384, 512, 20)      0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 192, 256, 20)      0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 192, 256, 40)      3240
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 192, 256, 40)      14440
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 192, 256, 40)      160
# _________________________________________________________________
# activation_13 (Activation)   (None, 192, 256, 40)      0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 96, 128, 40)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 96, 128, 80)       12880
# _________________________________________________________________
# conv2d_48 (Conv2D)           (None, 96, 128, 80)       57680
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 96, 128, 80)       320
# _________________________________________________________________
# activation_14 (Activation)   (None, 96, 128, 80)       0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 48, 64, 80)        0
# _________________________________________________________________
# conv2d_49 (Conv2D)           (None, 48, 64, 160)       51360
# _________________________________________________________________
# conv2d_50 (Conv2D)           (None, 48, 64, 160)       230560
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 48, 64, 160)       640
# _________________________________________________________________
# activation_15 (Activation)   (None, 48, 64, 160)       0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 24, 32, 160)       0
# _________________________________________________________________
# conv2d_transpose_22 (Conv2DT (None, 48, 64, 320)       205120
# _________________________________________________________________
# conv2d_51 (Conv2D)           (None, 48, 64, 320)       921920
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 48, 64, 320)       0
# _________________________________________________________________
# conv2d_transpose_23 (Conv2DT (None, 96, 128, 160)      204960
# _________________________________________________________________
# conv2d_52 (Conv2D)           (None, 96, 128, 160)      230560
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 96, 128, 160)      0
# _________________________________________________________________
# conv2d_transpose_24 (Conv2DT (None, 192, 256, 80)      51280
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 192, 256, 80)      57680
# _________________________________________________________________
# re_lu_12 (ReLU)              (None, 192, 256, 80)      0
# _________________________________________________________________
# conv2d_transpose_25 (Conv2DT (None, 384, 512, 40)      12840
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 384, 512, 40)      14440
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 384, 512, 40)      0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 384, 512, 40)      0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 384, 512, 3)       123
# =================================================================
# Total params: 8,037,486
# Trainable params: 2,073,563
# Non-trainable params: 5,963,923
# _________________________________________________________________

# %%
model_2.compile(optimizer=optimizer, loss=loss, metrics=metrics)

import os
from datetime import datetime

cwd = os.getcwd()

exps_dir = os.path.join(cwd, 'drive/My Drive/Keras4/', 'multiclass_segmentation_experiments')
if not os.path.exists(exps_dir):
    os.makedirs(exps_dir)

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'concatenated'

exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
if not os.path.exists(exp_dir):
    os.makedirs(exp_dir)
    
callbacks = []

# Model checkpoint
# ----------------
ckpt_dir = os.path.join(exp_dir, 'ckpts')
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)

ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp_{epoch:02d}.ckpt'), 
                                                   save_weights_only=True) 
callbacks.append(ckpt_callback)

# Visualize Learning on Tensorboard
# ---------------------------------
tb_dir = os.path.join(exp_dir, 'tb_logs')
if not os.path.exists(tb_dir):
    os.makedirs(tb_dir)
    
# By default shows losses and metrics for both training and validation
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir,
                                             profile_batch=0,
                                             histogram_freq=0)  
callbacks.append(tb_callback)

# Early Stopping
# --------------
early_stop = True
if early_stop:
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
    callbacks.append(es_callback)


history = model_2.fit(x=train_dataset,
          epochs=20,  #### set repeat in training dataset
          steps_per_epoch=len(dataset),
          validation_data=valid_dataset,
          validation_steps=len(dataset_valid), 
          callbacks=callbacks)
# Out:
# Epoch 1/20
# 144/144 [==============================] - 1386s 10s/step - loss: 0.3346 - accuracy: 0.8677 - meanIoU: 0.0068 - val_loss: 0.2840 - val_accuracy: 0.9345 - val_meanIoU: 4.3896e-12
# Epoch 2/20
# 144/144 [==============================] - 1358s 9s/step - loss: 0.1338 - accuracy: 0.9348 - meanIoU: 0.0325 - val_loss: 0.2452 - val_accuracy: 0.9356 - val_meanIoU: 0.0104
# Epoch 3/20
# 144/144 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9495 - meanIoU: 0.2317
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-1ad910407551>", line 57, in <module>
#     callbacks=callbacks)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py", line 1141, in fit
#     return_dict=True)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py", line 1389, in evaluate
#     tmp_logs = self.test_function(iterator)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py", line 828, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py", line 862, in _call
#     results = self._stateful_fn(*args, **kwds)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py", line 2943, in __call__
#     filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py", line 1919, in _call_flat
#     ctx, args, cancellation_manager=cancellation_manager))
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py", line 560, in call
#     ctx=ctx)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py", line 60, in quick_execute
#     inputs, attrs, num_outputs)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 1132, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 358, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1452, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 734, in getmodule
#     f = module.__file__
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
#       MODEL SAVING
#------------------------------

out = '/content/drive/My Drive/'

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'Weedelec_Network'

model.save(out + '/' + model_name +'_' + now + '.h5')
model.save_weights(out + '/weights_' + model_name + '_' + now)

# %%
#       MODEL SAVING
#------------------------------

out = '/content/drive/My Drive/'

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'PeadNetwork'

model.save(out + '/' + model_name +'_' + now + '.h5')
model.save_weights(out + '/weights_' + model_name + '_' + now)

# %%
import time
import matplotlib.pyplot as plt

from PIL import Image

# %matplotlib inline

iterator = iter(valid_dataset)

# %%
fig, ax = plt.subplots(1, 3, figsize=(8, 8))
fig.show()
image, target = next(iterator)

image = image[0] 
target = target[0, ..., 0]

out_sigmoid = model.predict(x=tf.expand_dims(image, 0))


predicted_class = tf.argmax(out_sigmoid, -1)

out_sigmoid.shape

predicted_class = predicted_class[0, ...]

# Assign colors (just for visualization)
target_img = np.zeros([target.shape[0], target.shape[1], 3])
prediction_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, 3):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

prediction_img[np.where(predicted_class == 0)] = [0, 0, 0]
for i in range(1, 3):
  prediction_img[np.where(predicted_class == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(image))
ax[1].imshow(np.uint8(target_img))
ax[2].imshow(np.uint8(prediction_img))

fig.canvas.draw()
time.sleep(1)

# %%
#------------------------------
#       MODEL SAVING
#------------------------------

out = '/content/drive/My Drive/'

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'fourth_custom_network'

model.save(out + '/' + model_name +'_' + now + '.h5')
model.save_weights(out + '/weights_' + model_name + '_' + now)

# %%
from PIL import Image

class CustomDataSol(tf.keras.utils.Sequence):

  def __init__(self, dataset_dir, img_generator=None,
               preprocessing_function=None, out_shape=[512, 384],projects=['Weedelec','Pead','Roseau','Bipbip'],plants=['Haricot','Mais']):

    self.subset_filenames = []
    self.subset_direc = []
    self.projects = []
    self.plants = []
    self.dataset_dir = dataset_dir
    self.img_generator = img_generator
    self.preprocessing_function = preprocessing_function
    self.out_shape = out_shape

    for project in projects :
      for plant in plants :
        path=os.path.join(dataset_dir,project,plant)
        list = os.listdir(os.path.join(path,'Images'))
        number_files = len(list)
        for ii in range(0,number_files):
            self.subset_filenames.append(os.path.splitext(list[ii])[0])
            self.subset_direc.append(path)
            self.projects.append(project)
            self.plants.append(plant)
    
  def __len__(self):
    return len(self.subset_filenames)

  def __getitem__(self, index):
    # Read Image
    curr_filename = self.subset_filenames[index]
    curr_dir = self.subset_direc[index]
    curr_project = self.projects[index]
    if curr_project == 'Roseau' :
      img = Image.open(os.path.join(curr_dir, 'Images', curr_filename + '.png'))
    else :
      img = Image.open(os.path.join(curr_dir, 'Images', curr_filename + '.jpg'))

    # Resize image 
    img = img.resize(self.out_shape)
    img_arr = np.array(img)
    
    if self.preprocessing_function is not None:
        img_arr = self.preprocessing_function(255*img_arr)

    return img_arr

################################################################################
 # Encode array (start kit)

def rle_encode(img):
    '''
    img: numpy array, 1 - foreground, 0 - background
    Returns run length as string formatted
    '''
    pixels = img.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)


################################################################################

path_test = '/content/drive/My Drive/Keras_Tutorial_4/Development_Dataset/Test_Dev/'
test_set=CustomDataSol(path_test, 
                        img_generator=None,
                        projects=['Weedelec','Pead','Roseau','Bipbip'],
                        plants=['Mais','Haricot'])
test_dataset = tf.data.Dataset.from_generator(lambda: test_set,
                                               output_types= tf.float32,
                                               output_shapes=[img_h, img_w, 3])

test_dataset = test_dataset.batch(1)
iterator = iter(test_dataset)
#test_set.__len__()

submission_dict = {}
SIZE=[[1536,2048],[2464,3280],[819,1228],[3456,5184]]
for index in range(0,test_set.__len__()):#test_set.__len__()
      image = next(iterator)
      if test_set.projects[index]=='Bipbip':
        size_im=SIZE[0]
      elif test_set.projects[index]=='Pead':
        size_im=SIZE[1]
      elif test_set.projects[index]=='Roseau':
        size_im=SIZE[2]
      else:
        size_im=SIZE[3]
      img_name = os.path.splitext(test_set.subset_filenames[index])[0]
      submission_dict[img_name] = {}
      mask_arr =  model_2.predict(image)
      mask_arr = tf.image.resize(mask_arr, size_im, method='nearest')
      #mask_arr.size
      predicted_class = tf.argmax(mask_arr, -1)
      predicted_class = predicted_class[0, ...]
      prediction_img = np.zeros([size_im[0], size_im[1]]) # Here was the problem
      #prediction_img2 = np.zeros([size_im[0], size_im[1], 3])
  
      prediction_img[np.where(predicted_class == 0)] = 0
      #prediction_img2[np.where(predicted_class == 0)] = [0, 0, 0]
      for i in range(1, 3):
        prediction_img[np.where(predicted_class == i)] = i
        #prediction_img2[np.where(predicted_class == i)] = np.array(colors[i-1])[:3] * 255
      #fig, ax = plt.subplots(1, 2, figsize=(10, 10))
      #fig.show() 
      #print(np.uint8(prediction_img2).size)   
      #ax[0].imshow(np.uint8(prediction_img2))
      #ax[1].imshow(np.uint8(image[0]))
      #fig.canvas.draw()
      #time.sleep(1)

      submission_dict[img_name]['shape'] = size_im
      submission_dict[img_name]['team'] = test_set.projects[index]
      submission_dict[img_name]['crop'] = test_set.plants[index]
      submission_dict[img_name]['segmentation'] = {}
    
    # crop
      rle_encoded_crop = rle_encode(prediction_img == 1)
    # weed
      rle_encoded_weed = rle_encode(prediction_img == 2)

      submission_dict[img_name]['segmentation']['crop'] = rle_encoded_crop
      submission_dict[img_name]['segmentation']['weed'] = rle_encoded_weed
#print(submission_dict)

import json
with open('/content/drive/My Drive/submission.json', 'w') as file:
      json.dump(submission_dict, file)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:111: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
import os
import json
import numpy as np
from PIL import Image


def rle_decode(rle, shape):
    s = rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape)




# Just for completeness, here we show how the rle encoded mask
# is transformed back to a numpy array

# Read the submission.json file generated by the
# 'prepare_submission.py' script
with open('/content/drive/MyDrive/submission_prova.json', 'r') as f:
      submission_dict = json.load(f)

img_name = 'Weedelec_mais_2019-09-25T121103-128'
img_shape = submission_dict[img_name]['shape']

rle_encoded_crop = submission_dict[img_name]['segmentation']['crop']
rle_encoded_weed = submission_dict[img_name]['segmentation']['weed']

# Reconstruct crop and weed binary masks
crop_mask = rle_decode(rle_encoded_crop, shape=img_shape)
weed_mask = rle_decode(rle_encoded_weed, shape=img_shape)

# Reconstruct original mask
# weed_mask * 2 allows to convert ones into target 2 (weed label)
reconstructed_mask = crop_mask + (weed_mask * 2)

# Just for visualisation purposes, save RGB reconstructed mask
# Use again the dictionary in 'RGBtoTarget.txt'.
reconstructed_rgb_arr = np.zeros(shape=img_shape + [3])
reconstructed_rgb_arr[reconstructed_mask == 1] = [255, 255, 255]
reconstructed_rgb_arr[reconstructed_mask == 2] = [216, 67, 82]

reconstructed_rgb_img = Image.fromarray(
    np.uint8(reconstructed_rgb_arr))
reconstructed_rgb_img.save('/content/drive/MyDrive/rle_decoded_rgb_mask.png')

# %%
from google.colab import files
files.download("/content/drive/MyDrive/submission_prova.json")
